# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
# %matplotlib inline

# %%
def resident(x, t):
    lamda = (beta1*(x[1]+2*x[2]))
    sdot = rho - mu*x[0] - sigmaS*lamda*x[0]
    i1dot = sigmaS*lamda*x[0] - (mu+alpha1+(sigmaI*lamda))*x[1]
    d11dot = sigmaI*lamda*x[1] - (mu+alpha11)*x[2]
    return sdot,i1dot,d11dot

# %%
mu = 0.02
rho = 0.02
sigmaS = 1
sigmaI = 5

beta1=0.75
alpha1 = 0.1 - 0.157**2/0.2*(1 - np.exp(0.2*(beta1 - 0.75)/0.157))
alpha11 = 0.1 - 0.157**2/0.2*(1 - np.exp(0.2*((2*beta1) - 0.75)/0.157))

# %%
tmax2 = 2000
ts2 = np.linspace(0,200,tmax2)

# %% [markdown]
# # $\rho = 0$

# %%
rho = 0

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[1999]
I1=I1s[1999]
D11=D11s[1999]

# %%
print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 2.551013251197566e-05 I1 = -6.065352428388016e-13 D11 = 2.851644247060563e-09

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()

# %% [markdown]
# # $\rho = 0.001$

# %%
rho = 0.001

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[1999]
I1=I1s[1999]
D11=D11s[1999]

# %%
print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.048928158820108855 I1 = -3.673074170211624e-09 D11 = 1.1986208845782752e-08

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()

# %% [markdown]
# # $\rho = 0.002$

# %%
rho = 0.002

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[1999]
I1=I1s[1999]
D11=D11s[1999]

# %%
print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.09781221832471433 I1 = 2.9625299392486432e-08 D11 = 1.3794599826348112e-10

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()

# %% [markdown]
# # $\rho = 0.003$

# %%
rho = 0.003

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[1999]
I1=I1s[1999]
D11=D11s[1999]

# %%
print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.1465991708156111 I1 = 8.189906518892338e-06 D11 = -1.2915177313349104e-09

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()

# %% [markdown]
# # $\rho = 0.004$

# %%
rho = 0.004

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[1999]
I1=I1s[1999]
D11=D11s[1999]

# %%
print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.1899559050379172 I1 = 0.0015571988059789993 D11 = 2.6072299144539652e-05

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()

# %% [markdown]
# # $\rho = 0.005$

# %%
rho = 0.005

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[1999]
I1=I1s[1999]
D11=D11s[1999]

# %%
print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.1638791615391323 I1 = 0.011202176191118263 D11 = 0.002175817495982251

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()

# %% [markdown]
# # $\rho = 0.006$

# %%
rho = 0.006

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[1999]
I1=I1s[1999]
D11=D11s[1999]

# %%
print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.17722358737599864 I1 = 0.012049538571562773 D11 = 0.002366330007889884

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()

# %% [markdown]
# # $\rho = 0.007$

# %%
rho = 0.007

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[1999]
I1=I1s[1999]
D11=D11s[1999]

# %%
print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.18119506856196038 I1 = 0.016295773760551732 D11 = 0.005005059795793373

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()

# %% [markdown]
# # $\rho = 0.008$

# %%
rho = 0.008

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[1999]
I1=I1s[1999]
D11=D11s[1999]

# %%
print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.18029354660995137 I1 = 0.018222468504062457 D11 = 0.007052940897088381

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()

# %% [markdown]
# # $\rho = 0.009$

# %%
rho = 0.009

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[1999]
I1=I1s[1999]
D11=D11s[1999]

# %%
print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.18456133117744974 I1 = 0.01992039511477745 D11 = 0.008868452193731583

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()

# %% [markdown]
# # $\rho = 0.01$

# %%
rho = 0.01

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[1999]
I1=I1s[1999]
D11=D11s[1999]

# %%
print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.1872871603780372 I1 = 0.021814532993841344 D11 = 0.011487598374902057

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()
