# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
# %matplotlib inline

# %%
def resident(x, t):
    lamda = (beta1*(x[1]+2*x[2]))
    sdot = rho - mu*x[0] - sigmaS*lamda*x[0]
    i1dot = sigmaS*lamda*x[0] - (mu+alpha1+(sigmaI*lamda))*x[1]
    d11dot = sigmaI*lamda*x[1] - (mu+alpha11)*x[2]
    return sdot,i1dot,d11dot

# %%
mu = 0.02
rho = 0.02
sigmaS = 1
sigmaI = 5

beta1=0.75
alpha1 = 0.1 - 0.157**2/0.2*(1 - np.exp(0.2*(beta1 - 0.75)/0.157))
alpha11 = 0.1 - 0.157**2/0.2*(1 - np.exp(0.2*((2*beta1) - 0.75)/0.157))

# %%
tmax2 = 2000
ts2 = np.linspace(0,200,tmax2)

# %% [markdown]
# # $\sigma_I = 0$

# %%
sigmaI=0

x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[1999]
I1=I1s[1999]
D11=D11s[1999]

print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.16000102675471303 I1 = 0.13999972534169877 D11 = -4.2587146736435186e-10

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()

# %% [markdown]
# # $\sigma_I = 0.1$

# %%
sigmaI=0.1

x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[1999]
I1=I1s[1999]
D11=D11s[1999]

print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.16312505224663545 I1 = 0.128493603351227 D11 = 0.004156947608100601

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()

# %% [markdown]
# # $\sigma_I = 0.15$

# %%
sigmaI=0.15

x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[1999]
I1=I1s[1999]
D11=D11s[1999]

print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.1645072495214312 I1 = 0.12356109396706073 D11 = 0.0059358493766060545

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()

# %% [markdown]
# # $\sigma_S = 0.16$

# %%
sigmaS=0.16

x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[1999]
I1=I1s[1999]
D11=D11s[1999]

print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.9830280412610635 I1 = 0.0004983567848417955 D11 = 3.021672367184897e-06

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()

# %% [markdown]
# # $\sigma_S = 0.17$

# %%
sigmaS=0.17

x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[1999]
I1=I1s[1999]
D11=D11s[1999]

print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.9785044201090007 I1 = 0.0012977699347698234 D11 = 2.007891749142964e-05

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()

# %% [markdown]
# # $\sigma_S = 0.18$

# %%
sigmaS=0.18

x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[1999]
I1=I1s[1999]
D11=D11s[1999]

print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.9697151662154746 I1 = 0.0030942724270998203 D11 = 0.00011546875897424178

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()

# %% [markdown]
# # $\sigma_S = 0.19$

# %%
sigmaS=0.19

x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[1999]
I1=I1s[1999]
D11=D11s[1999]

print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.952847055403375 I1 = 0.006464785864450453 D11 = 0.0005385379683565489

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()

# %% [markdown]
# # $\sigma_S = 0.2$

# %%
sigmaS=0.2

x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[1999]
I1=I1s[1999]
D11=D11s[1999]

print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.9232354774538654 I1 = 0.011229458502902434 D11 = 0.0018631182284451523

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()

# %% [markdown]
# # $\sigma_S = 0.3$

# %%
sigmaS=0.3

x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[1999]
I1=I1s[1999]
D11=D11s[1999]

print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.6362610827740894 I1 = 0.023306659572688685 D11 = 0.01376910711590928

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()

# %% [markdown]
# # $\sigma_S = 0.4$

# %%
sigmaS=0.4

x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[1999]
I1=I1s[1999]
D11=D11s[1999]

print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.47845479646602085 I1 = 0.026391228994215567 D11 = 0.02230603285350322

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()
