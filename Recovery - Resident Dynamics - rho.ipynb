# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
# %matplotlib inline

# %%
def resident(x, t):
    lamda = (beta1*(x[1]+x[2]))
    sdot = rho - mu*x[0] - sigmaS*lamda*x[0] + phi1*x[1] + phi11*x[2]
    i1dot = sigmaS*lamda*x[0] - (mu+alpha1+phi1+(sigmaI*lamda))*x[1]
    d11dot = sigmaI*lamda*x[1] - (mu+alpha1+phi11)*x[2]
    return sdot,i1dot,d11dot

# %%
mu = 0.02
rho = 0.02
sigmaS = 1
sigmaI = 5
phi1 = 0.4
phi11 = 0.2

beta1=0.75
alpha1 = 0.1 - 0.157**2/0.2*(1 - np.exp(0.2*(beta1 - 0.75)/0.157))

phim = 0.45
phi1m = 0.25

# %%
tmax2 = 5000
ts2 = np.linspace(0,500,tmax2)

# %% [markdown]
# # $\rho = 0.01$

# %%
rho = 0.01

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[4999]
I1=I1s[4999]
D11=D11s[4999]

# %%
print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.4999902224142028 I1 = 5.817969861013643e-12 D11 = -2.7292390277113482e-12

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,500))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.title(r'$\rho = 0.01$')
plt.show()

### S, I & D coexist for these parameter values

# %% [markdown]
# # $\rho = 0.012$

# %%
rho = 0.012

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[4999]
I1=I1s[4999]
D11=D11s[4999]

# %%
print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.5999833099891558 I1 = 8.298698352744899e-11 D11 = -4.601073955136972e-11

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,500))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.title(r'$\rho = 0.012$')
plt.show()

### S, I & D coexist for these parameter values

# %% [markdown]
# # $\rho = 0.014$

# %%
rho = 0.014

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[4999]
I1=I1s[4999]
D11=D11s[4999]

# %%
print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.6997944898103967 I1 = 3.606388288363409e-05 D11 = 1.4792322107280726e-08

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,500))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.title(r'$\rho = 0.014$')
plt.show()

### S, I & D coexist for these parameter values

# %% [markdown]
# # $\rho = 0.015$

# %%
rho = 0.015

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[4999]
I1=I1s[4999]
D11=D11s[4999]

# %%
print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.6614684959812388 I1 = 0.016093811639254437 D11 = 0.0034510934350666907

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,500))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.title(r'$\rho = 0.015$')
plt.show()

### S, I & D coexist for these parameter values

# %% [markdown]
# # $\rho = 0.016$

# %%
rho = 0.016

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[4999]
I1=I1s[4999]
D11=D11s[4999]

# %%
print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.6440946263323005 I1 = 0.022774492901554044 D11 = 0.00754831741290421

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,500))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.title(r'$\rho = 0.016$')
plt.show()

### S, I & D coexist for these parameter values

# %% [markdown]
# # $\rho = 0.018$

# %%
rho = 0.018

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[4999]
I1=I1s[4999]
D11=D11s[4999]

# %%
print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.587458946344514 I1 = 0.03278141561519298 D11 = 0.020733256462247076

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,500))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.title(r'$\rho = 0.018$')
plt.show()

### S, I & D coexist for these parameter values

# %% [markdown]
# # $\rho = 0.02$

# %%
rho = 0.02

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[4999]
I1=I1s[4999]
D11=D11s[4999]

# %%
print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.5715560159873672 I1 = 0.03893776570460703 D11 = 0.03268779461978127

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,500))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.title(r'$\rho = 0.02$')
plt.show()

### S, I & D coexist for these parameter values

# %% [markdown]
# # $\rho = 0.022$

# %%
rho = 0.022

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[4999]
I1=I1s[4999]
D11=D11s[4999]

# %%
print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.5559798681234303 I1 = 0.04396227707726655 D11 = 0.046709194216377724

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,500))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.title(r'$\rho = 0.022$')
plt.show()

### S, I & D coexist for these parameter values

# %% [markdown]
# # $\rho = 0.025$

# %%
rho = 0.025

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[4999]
I1=I1s[4999]
D11=D11s[4999]

# %%
print("S =",S, "I1 =",I1, "D11 =", D11)
# Out:
# S = 0.5382351718463275 I1 = 0.04963147534596476 D11 = 0.06899587492736771

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,500))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.title(r'$\rho = 0.025$')
plt.show()

# %% [markdown]
# # $\rho = 0.05$

# %%
rho = 0.05

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)
Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

S=Ss[4999]
I1=I1s[4999]
D11=D11s[4999]

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,500))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.title(r'$\rho = 0.05$')
plt.show()

### S, I & D coexist for these parameter values
